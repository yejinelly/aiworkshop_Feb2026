# %% [markdown]
# # 🔍 AI Literature Review Tools Survey (2024-2025)
#
# **시장에 나와있는 Review Agent 도구들 종합 비교**
#
# ---
#
# ## 목차
#
# 1. **상용 도구** - Literature Review & Research Assistants
# 2. **시각화 도구** - Citation Mapping & Visualization
# 3. **체계적 문헌고찰** - Systematic Review Automation
# 4. **Deep Research Agents** - 2024-2025 신규
# 5. **오픈소스** - GitHub Projects
# 6. **실습 & 토론**

# %% [markdown]
# ---
#
# ## 1. 상용 Literature Review 도구
#
# ### 핵심 도구 비교표
#
# | 도구 | 논문 수 | 핵심 기능 | 가격 | Best For |
# |------|--------:|----------|------|----------|
# | **Elicit** | 125M | 질문 기반 검색, 데이터 추출 | Free/$10/$42 | 체계적 문헌고찰 |
# | **Consensus** | - | 과학적 합의 분석 (Yes/No) | Free/$10 | 빠른 사실 확인 |
# | **SciSpace** | 280M | All-in-one (Chat, Write, Cite) | Free/$12 | 전체 워크플로우 |
# | **Semantic Scholar** | 225M | TLDR, Citation 분석 | **무료** | API 연동 |
# | **Scite** | 1.4B citations | Smart Citation (Support/Contrast) | $12-20 | 인용 신뢰도 |
# | **Undermind** | - | 98% precision, MIT PhD 개발 | Free/$16 | 복잡한 쿼리 |
# | **R Discovery** | 250M | 일일 추천, 오디오 논문 | Free/$12 | 논문 발견 |
# | **Keenious** | 200M | 문서 분석 → 논문 추천 | Free/기관 | Word/Docs 통합 |

# %% [markdown]
# ### 상세 분석
#
# ---
#
# #### 🔬 **Elicit** (elicit.com)
#
# | 항목 | 내용 |
# |------|------|
# | **핵심** | 질문 → 논문 검색 → 데이터 자동 추출 |
# | **강점** | 테이블 형태로 효과 크기, 표본 수 등 추출 |
# | **약점** | 월 PDF 제한, 비영어 논문 약함 |
# | **가격** | Free: 10 PDF/월 \| Plus: $10 \| Pro: $42 |
#
# ```
# 예시: "What is the effect of CBT on depression in adolescents?"
# → 관련 논문 + 효과 크기 + 표본 수 자동 추출
# ```
#
# ---
#
# #### 🎯 **Consensus** (consensus.app)
#
# | 항목 | 내용 |
# |------|------|
# | **핵심** | "Consensus Meter" - 과학적 합의 수준 |
# | **강점** | Yes/No 질문에 즉시 답변 + 근거 |
# | **약점** | 의학/과학 편중, 사회과학 약함 |
# | **가격** | Free: 25 검색/월 \| Premium: $10 (학생 40% 할인) |
#
# ```
# 예시: "Does meditation reduce anxiety?"
# → 82% Yes (based on 47 papers) + 개별 논문 인용
# ```
#
# ---
#
# #### 📚 **Semantic Scholar** (semanticscholar.org)
#
# | 항목 | 내용 |
# |------|------|
# | **핵심** | 225M+ 논문, TLDR 요약, Ask This Paper |
# | **강점** | **완전 무료**, API 제공, 임베딩(SPECTER) |
# | **약점** | 일부 분야 커버리지 부족 |
# | **운영** | Allen Institute for AI (비영리) |
#
# ---
#
# #### 📊 **Scite.ai** (scite.ai)
#
# | 항목 | 내용 |
# |------|------|
# | **핵심** | Smart Citation - Supporting vs Contrasting |
# | **강점** | 인용 맥락 분석, 논문 신뢰도 평가 |
# | **약점** | 비쌈 ($20/월) |
# | **가격** | 7일 무료 \| Personal: $12-20/월 |
#
# ---
#
# #### 🧠 **Undermind** (undermind.ai)
#
# | 항목 | 내용 |
# |------|------|
# | **핵심** | MIT 양자물리 PhD 개발, 98% precision |
# | **강점** | 전문가 수준 검색 프로세스 모방 |
# | **약점** | 신생 서비스 |
# | **가격** | Free: 10검색/월 \| Pro: $16/월 |

# %% [markdown]
# ---
#
# ## 2. Citation Mapping & Visualization
#
# | 도구 | 논문 수 | 핵심 기능 | 가격 |
# |------|--------:|----------|------|
# | **ResearchRabbit** | S2 기반 | 논문 네트워크 시각화 | Free/$15 |
# | **Litmaps** | 270M | 시간순 문헌 맵핑 | Free/$12.50 |
# | **Connected Papers** | 200M | 인용 그래프 (1개 seed) | Free/$3 |
#
# ---
#
# #### 🐰 **ResearchRabbit** (researchrabbit.ai)
#
# - "Spotify for Papers" - 시드 논문 → 관련 논문 네트워크
# - **Litmaps에 인수됨** (2024)
# - Free: 50 inputs, 1 project | RR+: $15/월 (2025~)
#
# ---
#
# #### 🗺️ **Litmaps** (litmaps.com)
#
# - 시간순 citation 그래프
# - Zotero 통합 (premium)
# - Free: 20 inputs, 2 maps/월
#
# ---
#
# #### 🕸️ **Connected Papers** (connectedpapers.com)
#
# - 1개 논문 → 관련 논문 그래프 생성
# - 노드 크기 = 인용 수, 색상 = 연도
# - Free: 2 graphs/월

# %% [markdown]
# ---
#
# ## 3. Systematic Review Automation
#
# | 도구 | 핵심 기능 | 가격 | 사용자 |
# |------|----------|------|--------|
# | **Rayyan** | AI 스크리닝, PRISMA | Free/Premium | 1M+ |
# | **Covidence** | 전체 SR 워크플로우 | Cochrane 무료 | - |
# | **DistillerSR** | 기업용 SR | 학생 무료 4개월 | - |
# | **EPPI-Reviewer** | UCL 개발 | 구독제 | - |
#
# ---
#
# #### 🔍 **Rayyan** (rayyan.ai)
#
# | 항목 | 내용 |
# |------|------|
# | **핵심** | AI 스크리닝 (90% 시간 절약) |
# | **기능** | 자동 중복 제거, PRISMA 다이어그램, 모바일 앱 |
# | **가격** | Free: 3 active reviews \| Premium: PICO 필터 |
# | **사용자** | 1백만+ 연구자 |
#
# ---
#
# #### 📋 **Covidence** (covidence.org)
#
# | 항목 | 내용 |
# |------|------|
# | **핵심** | 전체 SR 워크플로우 관리 |
# | **가격** | Cochrane 저자 무료 \| 개인 ~$240/리뷰 \| 학생 $15/월 |

# %% [markdown]
# ---
#
# ## 4. Deep Research Agents (2024-2025 신규)
#
# ### 주요 플레이어
#
# | 도구 | 개발사 | 핵심 기능 | 가격 |
# |------|--------|----------|------|
# | **Perplexity Deep Research** | Perplexity | 2-4분 종합 보고서 | Free 5/월, Pro 250/월 |
# | **Google Gemini Deep Research** | Google | Gemini 3 Pro 기반 | Gemini 구독 |
# | **OpenAI Deep Research** | OpenAI | o3/o4-mini 모델 | Free 5/월, Pro 250/월 |
# | **Google AI Co-Scientist** | Google | 가설 생성 에이전트 팀 | Research Preview |
# | **Ai2 ScholarQA** | Allen AI | 8M full-text + S2 | 무료 |
# | **Web of Science RA** | Clarivate | WoS 기반 AI 리뷰 | WoS 구독 필요 |
#
# ---
#
# #### 🔮 **Perplexity Deep Research**
#
# - 멀티스텝 웹 리서치 → 종합 보고서
# - Academic Focus 모드 (학술 소스 우선)
# - 93.9% 정확도 (SimpleQA 벤치마크)
# - 100+ 인용 포함 문헌고찰 생성
#
# ---
#
# #### 🧪 **Google AI Co-Scientist**
#
# - Gemini 2.0 기반 에이전트 팀
# - 새로운 연구 가설 자동 생성
# - 실험 설계 제안
# - Research Preview (제한적 접근)

# %% [markdown]
# ---
#
# ## 5. 오픈소스 GitHub 프로젝트
#
# ### 주요 프로젝트
#
# | 프로젝트 | Stars | 핵심 기능 | 링크 |
# |----------|------:|----------|------|
# | **GPT-Researcher** | 13k+ | 자율 리서치 에이전트 | [GitHub](https://github.com/assafelovic/gpt-researcher) |
# | **Paper-QA (PaperQA2)** | 4k+ | Scientific PDF RAG | [GitHub](https://github.com/Future-House/paper-qa) |
# | **LitLLM** | - | 문헌고찰 생성 (ServiceNow) | [GitHub](https://github.com/LitLLM/LitLLM) |
# | **AI-Researcher** | - | 전체 연구 자동화 (HKUDS) | [GitHub](https://github.com/HKUDS/AI-Researcher) |
# | **Open Deep Research** | - | LangChain 멀티에이전트 | [GitHub](https://github.com/langchain-ai/open_deep_research) |
# | **DeepResearch** | - | Alibaba NLP | [GitHub](https://github.com/Alibaba-NLP/DeepResearch) |

# %%
# GitHub에서 Literature Review Agent 검색
import requests

def search_github(query, max_results=10):
    url = "https://api.github.com/search/repositories"
    params = {"q": query, "sort": "stars", "per_page": max_results}

    resp = requests.get(url, params=params, timeout=10)
    items = resp.json().get("items", [])

    print(f"\n🔍 '{query}'")
    print("=" * 60)

    for i, item in enumerate(items, 1):
        print(f"\n{i}. ⭐ {item['stargazers_count']:,} | {item['full_name']}")
        desc = item['description'][:70] if item['description'] else 'No description'
        print(f"   {desc}")
        print(f"   🔗 {item['html_url']}")

search_github("literature review agent LLM")

# %%
search_github("paper qa pdf RAG")

# %%
search_github("systematic review automation")

# %% [markdown]
# ### 오픈소스 상세
#
# ---
#
# #### 🤖 **GPT-Researcher**
#
# ```python
# pip install gpt-researcher
#
# from gpt_researcher import GPTResearcher
#
# researcher = GPTResearcher(
#     query="Effects of LLMs on academic writing",
#     report_type="research_report"
# )
# report = await researcher.conduct_research()
# ```
#
# - 자율 웹 검색 + 보고서 생성
# - 5-6페이지 인용 포함 보고서
# - LangGraph 멀티에이전트
# - **OpenAI API 필요**
#
# ---
#
# #### 📄 **Paper-QA (PaperQA2)**
#
# ```python
# pip install paper-qa
#
# from paperqa import Docs
#
# docs = Docs()
# docs.add("paper.pdf")
# answer = docs.query("What methods were used?")
# ```
#
# - Scientific PDF 전용 RAG
# - Superhuman QA 성능 (벤치마크)
# - Future House (구 LitQA) 개발
#
# ---
#
# #### 📝 **LitLLM** (ServiceNow + Mila)
#
# - Related Work 섹션 자동 생성
# - RAG 기반 문헌고찰
# - TMLR 2024 논문 발표

# %% [markdown]
# ---
#
# ## 6. 실습 링크
#
# ### 🔗 Quick Access
#
# | 도구 | 링크 | 테스트 쿼리 |
# |------|------|-------------|
# | Elicit | [elicit.com](https://elicit.com) | "What reduces depression in teens?" |
# | Consensus | [consensus.app](https://consensus.app) | "Does exercise improve memory?" |
# | Semantic Scholar | [semanticscholar.org](https://semanticscholar.org) | "transformer attention" |
# | ResearchRabbit | [researchrabbit.ai](https://researchrabbit.ai) | (시드 논문 필요) |
# | Connected Papers | [connectedpapers.com](https://connectedpapers.com) | (시드 논문 필요) |
# | Perplexity | [perplexity.ai](https://perplexity.ai) | "LLM emotion recognition research" |
# | Rayyan | [rayyan.ai](https://rayyan.ai) | (프로젝트 생성 필요) |

# %% [markdown]
# ---
#
# ## 7. 상황별 도구 선택 가이드
#
# ### 🎯 목적별 추천
#
# | 상황 | 1순위 | 2순위 | 이유 |
# |------|-------|-------|------|
# | **새 분야 탐색** | ResearchRabbit | Connected Papers | 시각적, 무료 |
# | **체계적 문헌고찰** | Elicit | Rayyan | 데이터 추출 |
# | **빠른 사실 확인** | Consensus | Perplexity | 즉시 답변 |
# | **인용 품질 확인** | Scite.ai | - | Support/Contrast |
# | **API 연동 개발** | Semantic Scholar | OpenAlex | 무료 API |
# | **종합 보고서** | Perplexity Deep | GPT-Researcher | 자동화 |
# | **PDF 질의응답** | SciSpace | Paper-QA | Chat with PDF |
#
# ### 💰 예산별 추천
#
# | 예산 | 조합 |
# |------|------|
# | **무료** | Semantic Scholar + ResearchRabbit + Consensus Free |
# | **$10-15/월** | Elicit Plus + Litmaps |
# | **$30+/월** | Elicit Pro + Scite.ai |

# %% [markdown]
# ---
#
# ## 8. 2024-2025 트렌드
#
# ### 주요 변화
#
# 1. **Deep Research Agents 등장**
#    - Google, OpenAI, Perplexity 모두 에이전트 기반 리서치 출시
#
# 2. **Freemium 확대**
#    - Elicit, ResearchRabbit 무료 티어 강화
#
# 3. **인수합병**
#    - ResearchRabbit → Litmaps 인수
#    - Scite → Research Solutions 합병
#
# 4. **오픈소스 성장**
#    - GPT-Researcher, Paper-QA 활발
#
# 5. **PRISMA-AI 가이드라인**
#    - 체계적 문헌고찰에서 AI 사용 보고 기준 (PRISMA-trAIce)
#
# 6. **기관 도입**
#    - Web of Science, Scopus에 AI 어시스턴트 추가

# %% [markdown]
# ---
#
# ## 9. 토론 주제
#
# ### 💬 Discussion
#
# 1. **정확성 vs 편의성**
#    - AI 요약의 할루시네이션 어떻게 검증?
#
# 2. **연구 윤리**
#    - AI 도구 사용을 논문에 어떻게 보고?
#    - PRISMA-AI 가이드라인 준수?
#
# 3. **무료 vs 유료**
#    - 유료 도구의 가치는 충분한가?
#
# 4. **미래 전망**
#    - 5년 후 문헌고찰 과정은?
#
# ### 📊 투표
#
# 가장 유용하다고 생각하는 도구?
# - [ ] Elicit
# - [ ] Consensus
# - [ ] Semantic Scholar
# - [ ] ResearchRabbit
# - [ ] Perplexity
# - [ ] Other: ________

# %% [markdown]
# ---
#
# ## 참고 자료
#
# ### 📚 Further Reading
#
# - [Avidnote: Top 10 AI Tools 2025](https://avidnote.com/top-10-ai-tools-for-research-in-2025/)
# - [Aaron Tay: Rise of Deep Research Agents](https://aarontay.substack.com/p/the-rise-of-agent-based-deep-research)
# - [PRISMA-AI Guidelines](https://www.prisma-statement.org/)
#
# ### 🔗 API 문서
#
# - [Semantic Scholar API](https://api.semanticscholar.org/)
# - [OpenAlex API](https://docs.openalex.org/)
# - [PubMed E-utilities](https://www.ncbi.nlm.nih.gov/books/NBK25500/)
#
# ---
#
# *SNU AI Psychology Workshop - February 2026*
# *Last updated: 2026-01-17*
